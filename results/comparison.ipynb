# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

results = pd.read_csv('/content/drive/My Drive/DSAN6500_Project/TILS_project/results/Results_AllModels.csv')

results.head()
# Out:
# Mounted at /content/drive
#        Model  Epoch  Training Loss  Validation Loss  Test Loss  \
# 0        VGG     51       0.896409         0.557612   0.770671
# 1     ResNet     51       0.419560         0.665103   0.608108
# 2  GoogLeNet     51       0.102967         0.522244   0.562588
# 3    AlexNet     51       0.258036         0.613473   0.339365
#
#    Training Accuracy  Validation Accuracy  Test Accuracy  Training Precision  \
# 0           0.529412                  0.7       0.666667                   1
# 1           0.970588                  0.9       1.000000                   1
# 2           1.000000                  0.8       0.666667                   1
# 3           0.941176                  0.7       0.833333                   1
#
#    Training Recall  ...  Validation Precision  Validation Recall  \
# 0         0.533597  ...                     1           0.812500
# 1         0.972222  ...                     1           0.916667
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


training_accuracy_columns = ['Model', 'Training Accuracy', 'Training Top-5 Accuracy']


training_accuracy = results.loc[:, training_accuracy_columns]

print(training_accuracy)



training_accuracy_melted = training_accuracy.melt(id_vars='Model', var_name='Metric', value_name='Accuracy')

print(training_accuracy_melted)


palette = {'Training Accuracy': '#FF4F79', 'Training Top-5 Accuracy': '#A11692'}



plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Accuracy', hue='Metric', data=training_accuracy_melted, palette=palette)

# Add title and labels
plt.title('Comparison of Training Top-1 and Top-5 Accuracy by Model')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.ylim(0, 1.1)
plt.savefig('/content/drive/My Drive/DSAN6500_Project/TILS_project/results/training_accuracy_plot.png', format='png', dpi=300)
# Display the plot
plt.show()
# Out:
#        Model  Training Accuracy  Training Top-5 Accuracy
# 0        VGG           0.529412                 0.514286
# 1     ResNet           0.970588                 0.970563
# 2  GoogLeNet           1.000000                 1.000000
# 3    AlexNet           0.941176                 0.940972
#        Model                   Metric  Accuracy
# 0        VGG        Training Accuracy  0.529412
# 1     ResNet        Training Accuracy  0.970588
# 2  GoogLeNet        Training Accuracy  1.000000
# 3    AlexNet        Training Accuracy  0.941176
# 4        VGG  Training Top-5 Accuracy  0.514286
# 5     ResNet  Training Top-5 Accuracy  0.970563
# 6  GoogLeNet  Training Top-5 Accuracy  1.000000
# 7    AlexNet  Training Top-5 Accuracy  0.940972

# %%
validation_accuracy_columns = ['Model', 'Validation Accuracy', 'Validation Top-5 Accuracy']


validation_accuracy = results.loc[:, validation_accuracy_columns]

print(validation_accuracy)



validation_accuracy_melted = validation_accuracy.melt(id_vars='Model', var_name='Metric', value_name='Accuracy')

print(validation_accuracy_melted)


palette = {'Validation Accuracy': '#FF4F79', 'Validation Top-5 Accuracy': '#A11692'}



plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Accuracy', hue='Metric', data=validation_accuracy_melted, palette=palette)

# Add title and labels
plt.title('Comparison of Validation Top-1 and Top-5 Accuracy by Model')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.ylim(0, 1.1)
plt.savefig('/content/drive/My Drive/DSAN6500_Project/TILS_project/results/validation_accuracy_plot.png', format='png', dpi=300)
# Display the plot
plt.show()
# Out:
#        Model  Validation Accuracy  Validation Top-5 Accuracy
# 0        VGG                  0.7                   0.670330
# 1     ResNet                  0.9                   0.898990
# 2  GoogLeNet                  0.8                   0.791667
# 3    AlexNet                  0.7                   0.696970
#        Model                     Metric  Accuracy
# 0        VGG        Validation Accuracy  0.700000
# 1     ResNet        Validation Accuracy  0.900000
# 2  GoogLeNet        Validation Accuracy  0.800000
# 3    AlexNet        Validation Accuracy  0.700000
# 4        VGG  Validation Top-5 Accuracy  0.670330
# 5     ResNet  Validation Top-5 Accuracy  0.898990
# 6  GoogLeNet  Validation Top-5 Accuracy  0.791667
# 7    AlexNet  Validation Top-5 Accuracy  0.696970

# %%
test_accuracy_columns = ['Model', 'Test Accuracy', 'Test Top-5 Accuracy']


test_accuracy = results.loc[:, test_accuracy_columns]

print(test_accuracy)



test_accuracy_melted = test_accuracy.melt(id_vars='Model', var_name='Metric', value_name='Accuracy')

print(test_accuracy_melted)


palette = {'Test Accuracy': '#FF4F79', 'Test Top-5 Accuracy': '#A11692'}



plt.figure(figsize=(10, 6))
sns.barplot(x='Model', y='Accuracy', hue='Metric', data=test_accuracy_melted, palette=palette)

# Add title and labels
plt.title('Comparison of Test Top-1 and Top-5 Accuracy by Model')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.ylim(0, 1.1)
plt.savefig('/content/drive/My Drive/DSAN6500_Project/TILS_project/results/test_accuracy_plot.png', format='png', dpi=300)
# Display the plot
plt.show()
# Out:
#        Model  Test Accuracy  Test Top-5 Accuracy
# 0        VGG       0.666667             0.666667
# 1     ResNet       1.000000             1.000000
# 2  GoogLeNet       0.666667             0.666667
# 3    AlexNet       0.833333             0.828571
#        Model               Metric  Accuracy
# 0        VGG        Test Accuracy  0.666667
# 1     ResNet        Test Accuracy  1.000000
# 2  GoogLeNet        Test Accuracy  0.666667
# 3    AlexNet        Test Accuracy  0.833333
# 4        VGG  Test Top-5 Accuracy  0.666667
# 5     ResNet  Test Top-5 Accuracy  1.000000
# 6  GoogLeNet  Test Top-5 Accuracy  0.666667
# 7    AlexNet  Test Top-5 Accuracy  0.828571
